# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.ones(100)  # Constant y values

# Creating a gradient background for the range moving along the x-axis
range_values = np.linspace(0, 1, 100).reshape(1, -1)  # Range from 0 to 1, reshaped for broadcasting

plt.imshow(range_values, cmap='cool', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.3)
plt.plot(x, y, color='black')  # Add a line (for example, a black line) representing y = 1

plt.title('Safe to Dangerous Levels')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where((x <= 10) | (x > 30), 0, (x - 10) / 20)
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.imshow(range_values, cmap='cool', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.3)
plt.plot(x, y, color='black')  # Add a line (for example, a black line) representing y = 1

plt.title('Health Status')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.imshow(range_values, cmap='cool', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.3)
plt.plot(x, y, color='black')  # Add a line (for example, a black line) representing y = 1

plt.title('Health Status')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.imshow(range_values, cmap='RdYlGn', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.title('Health Status')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.title('Health Status')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.title('Health Status')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis
plt.ylim(0.9, 1.1)  # Set the y-axis limit to control the visible height

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.figure(figsize=(6, 3))  # Set the figure size to be narrower (6 inches wide, 3 inches tall)

plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.title('Health Status')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis
plt.ylim(0.9, 1.1)  # Set the y-axis limit to control the visible height

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.figure(figsize=(6, 1))  # Set the figure size to be one-to-one (6 inches wide, 6 inches tall)

plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis ticks

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.figure(figsize=(6, 1))  # Set the figure size to be one-to-one (6 inches wide, 1 inch tall)

plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis ticks

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.figure(figsize=(6, 1))  # Set the figure size to be one-to-one (6 inches wide, 1 inch tall)

plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis ticks

# Define custom x-axis ticks and labels
custom_ticks = [5, 15, 25, 35]  # Set the positions of the ticks
custom_labels = ['A', 'B', 'C', 'D']  # Corresponding labels for the ticks

plt.xticks(custom_ticks, custom_labels)  # Set the custom ticks and labels

# Draw vertical lines at the tick positions
for tick in custom_ticks:
    plt.axvline(x=tick, color='black', linestyle='--', linewidth=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.figure(figsize=(6, 1))  # Set the figure size to be one-to-one (6 inches wide, 1 inch tall)

plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis ticks

# Define specific x-axis ticks and draw vertical lines at those points
limits = [10, 30]  # Set the positions of the ticks

plt.xticks(limits, ['A', 'B'])  # Set the custom ticks and labels

# Draw vertical lines at the specific tick positions
for limit in limits:
    plt.axvline(x=limit, color='black', linestyle='--', linewidth=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.figure(figsize=(6, 1))  # Set the figure size to be one-to-one (6 inches wide, 1 inch tall)

plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis ticks

# Define specific x-axis ticks and draw vertical lines at those points
limits = [10, 30]  # Set the positions of the ticks

tick_labels = ['A', 'B']  # Initial labels for the ticks

for limit, label in zip(limits, tick_labels):
    plt.axvline(x=limit, color='black', linestyle='--', linewidth=0.5)
    if limit == 10:
        plt.text(limit - 0.5, 0.5, label, rotation=90, ha='center', va='center')
    else:
        plt.text(limit + 0.5, 0.5, label, rotation=-90, ha='center', va='center')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.figure(figsize=(6, 1))  # Set the figure size to be one-to-one (6 inches wide, 1 inch tall)

plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis ticks

# Define specific x-axis ticks and draw vertical lines at those points
limits = [10, 30]  # Set the positions of the ticks

tick_labels = ['A', 'B']  # Initial labels for the ticks

for limit, label in zip(limits, tick_labels):
    plt.axvline(x=limit, color='black', linestyle='--', linewidth=0.5)
    if limit == 10:
        plt.text(limit - 0.5, 0.5, label, rotation=90, ha='center', va='center')
    else:
        plt.text(limit + 0.5, 0.5, label, rotation=-90, ha='center', va='center')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.figure(figsize=(6, 1))  # Set the figure size to be one-to-one (6 inches wide, 1 inch tall)

plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis ticks

# Define specific x-axis ticks and draw vertical lines at those points
limits = [10, 30]  # Set the positions of the ticks

tick_labels = ['A', 'B']  # Initial labels for the ticks

for limit, label in zip(limits, tick_labels):
    plt.axvline(x=limit, color='black', linestyle='--', linewidth=0.5)
    if limit == 10:
        plt.text(limit - 0.5, 0.5, label, rotation=90, ha='center', va='center')
    else:
        plt.text(limit + 0.5, 0.5, label, rotation= -90, ha='center', va='center')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.figure(figsize=(6, 1))  # Set the figure size to be one-to-one (6 inches wide, 1 inch tall)

plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis ticks

# Define specific x-axis ticks and draw vertical lines at those points
limits = [10, 30]  # Set the positions of the ticks

tick_labels = ['A', 'B']  # Initial labels for the ticks

for limit, label in zip(limits, tick_labels):
    plt.axvline(x=limit, color='black', linestyle='--', linewidth=0.5)
    if limit == 10:
        plt.text(limit - 0.5, 0.5, label, rotation=90, ha='center', va='center')
    else:
        plt.text(limit + 0.5, 0.5, label, rotation=-90, ha='center', va='center')

# Constant value to be drawn inside the chart
custom_value = 35
plt.text(custom_value, 0.5, str(custom_value), color='white', ha='center', va='center')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 40, 100)  # Expanded x range
y = np.ones(100)  # Constant y values

# Creating a gradient background for healthy and sick individuals
range_values = np.where(x <= 10, 0, np.where(x > 30, 1, (x - 10) / 20))
range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

plt.figure(figsize=(6, 1))  # Set the figure size to be one-to-one (6 inches wide, 1 inch tall)

plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
plt.plot(x, y, color='black')  # Add a line representing y = 1

plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis ticks

# Define specific x-axis ticks and draw vertical lines at those points
limits = [10, 30]  # Set the positions of the ticks

tick_labels = ['A', 'B']  # Initial labels for the ticks

for limit, label in zip(limits, tick_labels):
    plt.axvline(x=limit, color='black', linestyle='--', linewidth=0.5)
    if limit == 10:
        plt.text(limit - 0.5, 0.5, label, rotation=90, ha='center', va='center')
    else:
        plt.text(limit + 0.5, 0.5, label, rotation=-90, ha='center', va='center')

# Constant value represented as a highlighted vertical line
custom_value = 6
plt.axvline(x=custom_value, color='red', linestyle='-', linewidth=2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def two_limits(patient, lwst, bgst, keylwst, keybgst, constant):
    x = np.linspace(0, 40, 100)  # Expanded x range
    y = np.ones(100)  # Constant y values

    # Creating a gradient background for healthy and sick individuals
    range_values = np.where(x <= lwst, 0, np.where(x > bgst, 1, (x - 10) / 20))
    range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

    plt.figure(figsize=(6, 1))  # Set the figure size to be one-to-one (6 inches wide, 1 inch tall)

    plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x[0], x[-1], 0, 1], alpha=0.7)
    plt.plot(x, y, color='black')  # Add a line representing y = 1

    plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis ticks

    # Define specific x-axis ticks and draw vertical lines at those points
    limits = [lwst, bgst]  # Set the positions of the ticks

    tick_labels = [keylwst, keybgst]  # Initial labels for the ticks

    for limit, label in zip(limits, tick_labels):
        plt.axvline(x=limit, color='black', linestyle='--', linewidth=0.5)
        if limit == 10:
            plt.text(limit - 0.5, 0.5, label, rotation=90, ha='center', va='center')
        else:
            plt.text(limit + 0.5, 0.5, label, rotation=-90, ha='center', va='center')

    # Constant value represented as a highlighted vertical line
    custom_value = patient
    plt.axvline(x=custom_value, color='red', linestyle='-', linewidth=2)

    plt.show()

def trial():
    constant = 2 * (abs(0.6 - 0.8)) / 3
    fig = two_limits(0.3, 0.6, 0.8, "optimal düzey <", "artmış kardiovasküler hastalık riski >", constant)

trial()

# %%
import matplotlib.pyplot as plt
import numpy as np

def two_limits(patient, lwst, bgst, keylwst, keybgst, constant):
    x_min = min(lwst, bgst) - constant  # Adjust the minimum x-axis value
    x_max = max(lwst, bgst) + constant  # Adjust the maximum x-axis value

    x = np.linspace(x_min, x_max, 1000)  # Adjust x range based on limits
    y = np.ones(1000)  # Constant y values

    # Adjust the x-axis limits if the patient value is outside the range
    if patient < x_min:
        x_min = patient - constant
    if patient > x_max:
        x_max = patient + constant

    # Creating a gradient background for healthy and sick individuals within the specified x-range
    range_values = np.where(x <= lwst, 0, np.where(x > bgst, 1, (x - lwst) / (bgst - lwst)))
    range_values = range_values.reshape(1, -1)  # Reshaping for broadcasting

    plt.figure(figsize=(6, 1))  # Set the figure size for a wider display

    plt.imshow(range_values, cmap='RdYlGn_r', aspect='auto', extent=[x_min, x_max, 0, 1], alpha=0.7)
    plt.plot(x, y, color='black')  # Add a line representing y = 1

    plt.gca().get_yaxis().set_visible(False)  # Hide the y-axis ticks

    # Define specific x-axis ticks and draw vertical lines at those points
    limits = [lwst, bgst]  # Set the positions of the ticks

    tick_labels = [keylwst, keybgst]  # Initial labels for the ticks

    for limit, label in zip(limits, tick_labels):
        plt.axvline(x=limit, color='black', linestyle='--', linewidth=1)
        if limit == lwst:
            plt.text(limit - 0.2, 0.5, label, rotation=90, ha='center', va='center', fontsize=8)
        else:
            plt.text(limit + 0.2, 0.5, label, rotation=-90, ha='center', va='center', fontsize=8)

    # Constant value represented as a highlighted vertical line, ensuring it's within the x-axis limits
    custom_value = max(x_min, min(patient, x_max))
    plt.axvline(x=custom_value, color='red', linestyle='-', linewidth=2)

    plt.show()

def trial():
    constant = 2 * (abs(5 - 10)) / 3
    fig = two_limits(7, 5, 10, "optimal düzey <", "artmış kardiovasküler hastalık riski >", constant)

trial()
